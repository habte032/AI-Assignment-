# %%
import string
import unicodedata
from collections import Counter

def compute_word_frequency(text):
    """Computes word frequency in the text."""
    words = text.split()
    word_freq = Counter(words)
    return word_freq

def compute_char_frequency(text):
    """Computes character frequency in the text."""
    char_freq = Counter(text)
    return char_freq

def display_word_frequency(word_freq):
    """Displays words in decreasing order of their frequency."""
    print("የቃላት ድግግሞሽ(Word Frequency):")
    print()
    for word, freq in word_freq.most_common():
        print(f"{word}: {freq}")
        print()

def display_char_frequency(char_freq):
    """Displays the first five most frequently occurring characters."""
    print("የፊደል ድግግሞሽ(Character Frequency):")
    for char, freq in char_freq.most_common(5):
        if char.isspace():
            continue
        print(f"{char}= {freq}")
        print()

def display_statistical_information(text):
    """Displays statistical information about the text."""
    lines = text.count('\n') + 1
    words = len(text.split())
    chars = len(text)
    print("ቁጥራዊ መርጃ(Statistical Information):")
    print()
    print(f"ጠቅላላ መስመር(Total Lines): {lines}")
    print()
    print(f"ጠቅላላ የቃላት ብዛት(Total Words): {words}")
    print()
    print(f"ጠቅላላ የፊደል ብዛት(Total Characters): {chars}")
 

# Read text file
#we can read both amaharic and English Text
with open("C:/Users/hm/Dropbox/My PC (LAPTOP-6M4OIP3C)/Desktop/AI project/amharic.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Remove special characters and normalize Amharic characters
text = "".join([char for char in text if char not in string.punctuation])
text = unicodedata.normalize('NFKD', text)

#word frequency
word_freq = compute_word_frequency(text)

# character frequency
char_freq = compute_char_frequency(text)
print()
# Display word frequency
display_word_frequency(word_freq)
print()
# Display character frequency
display_char_frequency(char_freq)
print()
# Display statistical information
display_statistical_information(text)
# Out:
# የቃላት ድግግሞሽ(Word Frequency):
#
# ላይ: 5
#
# ሰዎች: 4
#
# እና: 3
#
# መንግስት: 3
#
# ኮሪያ: 3
#
# ሁለት: 3
#
# ምክንያት: 2
#
# መካነ: 2
#
# አዲስ: 2
#
# ውስጥ: 2
#
# ነዳጅ: 2
#
# ከተማ: 2
#
# አደጋ: 2
#
# ግድያ: 2
#
# መሪ: 2
#
# የአፍሪካ: 2
#
# እንደሆነ: 2
#
# ኳስ: 2
#
# ግዛት: 2
#
# ወረርሽኝ: 2
#
# የቀድሞ: 2
#
# የመፈንቅለ: 2
#
# በላ: 2
#
# አራት: 2
#
# የሰሜን: 2
#
# አምላክ: 1
#
# የለሽ: 1
#
# አየርላንድ: 1
#
# የኢየሱስ: 1
#
# ክርስቶስን፣: 1
#
# መሐመድን፣: 1
#
# ሳልማን: 1
#
# ራሽዲን፣: 1
#
# ማርክ: 1
#
# ትዌንን: 1
#
# ርዕሰ: 1
#
# ሊቃነ: 1
#
# ጳጳሳት: 1
#
# ቤኔዲክት: 1
#
# 16ኛን: 1
#
# ንግግሮችን: 1
#
# ማተም: 1
#
# ስድብ: 1
#
# በመሆኑ: 1
#
# አዲሱ: 1
#
# ህግ: 1
#
# ቢከለክለውም: 1
#
# ሆን: 1
#
# ብሎ: 1
#
# በድረገጹ: 1
#
# አሳትሟል።: 1
#
# የግብፅ: 1
#
# የቁፋሮ: 1
#
# ተመራማሪዎች: 1
#
# በቀደምት: 1
#
# የሳቃራ: 1
#
# መቃብር: 1
#
# በጣም: 1
#
# ትልቅ: 1
#
# የሆነ: 1
#
# የመቃብር: 1
#
# ስፍራ: 1
#
# አገኙ።: 1
#
# በሻንቺ: 1
#
# ፣: 1
#
# ቻይና: 1
#
# የተከሰተው: 1
#
# የናፍጣ: 1
#
# መፍሰስ: 1
#
# በሚሊዮኖች: 1
#
# ለሚቆጠሩ: 1
#
# የውሃ: 1
#
# ምንጭ: 1
#
# ወደሆነው: 1
#
# የሎው: 1
#
# ወንዝ: 1
#
# ደረሰ።: 1
#
# ስሎቫኪያ: 1
#
# በአየርላንዷ: 1
#
# ዱብሊን: 1
#
# ዶርሴት: 1
#
# መንገድ: 1
#
# ንፁሃን: 1
#
# ባሉበት: 1
#
# አካባቢ: 1
#
# ስለጠቃጣው: 1
#
# የፈንጂ: 1
#
# ሀላፊነቱን: 1
#
# እንደምትወስድ: 1
#
# አስታወቀች።: 1
#
# በአውስትራሊያ: 1
#
# በሳምንቱ: 1
#
# መጨረሻ: 1
#
# የተፈጸመው: 1
#
# የህንድ: 1
#
# በዚያ: 1
#
# ሀገር: 1
#
# ለሚማሩ: 1
#
# የኮሌጅ: 1
#
# ተማሪዎቿ: 1
#
# ምክር: 1
#
# እንድትሰጥ: 1
#
# አነሳስቷል።: 1
#
# ሴኮባ: 1
#
# ኮናቴ: 1
#
# ጊኒ: 1
#
# የሚገኝ: 1
#
# ጁንታ: 1
#
# ጊዜያዊ: 1
#
# በመታመሙ: 1
#
# ወደ: 1
#
# ሴኔጋል: 1
#
# ተወሰደ።: 1
#
# የደቡብ: 1
#
# አፍሪካው: 1
#
# ፕሬዚደንት: 1
#
# ጃኮብ: 1
#
# ዙማ: 1
#
# የፓርቲያቸው: 1
#
# ህብረት: 1
#
# ኮንግረስ: 1
#
# የ98ኛ: 1
#
# አመት: 1
#
# ክብረ: 1
#
# በዓል: 1
#
# ከኢኪኖሚያዊው: 1
#
# ጫና: 1
#
# የሚያገግሙበት: 1
#
# አካሄድ: 1
#
# እየዘገየ: 1
#
# አስጠነቀቁ።: 1
#
# እግር: 1
#
# ኮንፌዴሬሽን: 1
#
# ጥቃቱ: 1
#
# በተፈጸመበት: 1
#
# በካቢንዳ: 1
#
# የእግር: 1
#
# ጨዋታዎች: 1
#
# እንደሚቀጥሉ: 1
#
# አስታወቀ።: 1
#
# የአውሮፓ: 1
#
# የጤንነት: 1
#
# ካውንስል: 1
#
# የሆነው: 1
#
# ዎልፍጋንገ: 1
#
# ዎዳርግ: 1
#
# የ2009: 1
#
# የጉንፋን: 1
#
# በመዳኒት: 1
#
# አቅራቢዎች: 1
#
# ክትባቶችን: 1
#
# ለመሸጥ: 1
#
# ሲባል: 1
#
# የተቀነባበረ: 1
#
# የውሸት: 1
#
# ተናገሩ።: 1
#
# በሺዎች: 1
#
# የሚቆጠሩ: 1
#
# የታሒ: 1
#
# ጠቅላይ: 1
#
# ሚኒሰቴር: 1
#
# ታህክሲን: 1
#
# ሺንዋትራ: 1
#
# ደጋፊዎች: 1
#
# በ2006: 1
#
# በተደረገባቸው: 1
#
# በንጉሳዊ: 1
#
# አማካሪ: 1
#
# ቤተመንግስት: 1
#
# ደጃፍ: 1
#
# በመገኘት: 1
#
# ተቃውሞአቸውን: 1
#
# አሰሙ።: 1
#
# በግብፅ: 1
#
# ራሚዶች: 1
#
# አጠገብ: 1
#
# የተገኙ: 1
#
# መቃብሮች፤: 1
#
# መቃብሮች: 1
#
# በባሪያዎች: 1
#
# ሳይሆን: 1
#
# በነፃ: 1
#
# እንደተሰሩ: 1
#
# ማረጋገጫዎች: 1
#
# እንደሚሆኑ: 1
#
# አስታወቁ።: 1
#
# በአየር: 1
#
# ሙቀት: 1
#
# እየተፈተነች: 1
#
# ያለችው: 1
#
# አውስትራሊያ: 1
#
# ከ1902: 1
#
# ሞቃታማ: 1
#
# የተባለውን: 1
#
# ምሽት: 1
#
# አሳልፋለች።: 1
#
# የቱርክ: 1
#
# ፖሊስ: 1
#
# እኤአ: 1
#
# በ: 1
#
# 2003: 1
#
# ዓም: 1
#
# ሴራ: 1
#
# ፈጽመዋል: 1
#
# ተብለው: 1
#
# የተጠረጠሩ: 1
#
# ጄኔራሎችን: 1
#
# ጨምሮ: 1
#
# ቢያንስ: 1
#
# አስራ: 1
#
# ወታደራዊ: 1
#
# መኮንኖችን: 1
#
# በቁጥጥር: 1
#
# ስር: 1
#
# አውሏል።: 1
#
# በአፍጋኒሳትን: 1
#
# ከአልቃይዳ: 1
#
# ዋና: 1
#
# አመራሮች: 1
#
# የነበረው: 1
#
# የኦሳማ: 1
#
# ቢላደን: 1
#
# ሶሰተኛ: 1
#
# አዛዥ: 1
#
# የነበርው: 1
#
# ሙሰጠፋ: 1
#
# አቡ: 1
#
# አል: 1
#
# ያዚድ: 1
#
# እንደተገደለ: 1
#
# ተነገረ።: 1
#
# ፖላንድ: 1
#
# ኤፕሪል: 1
#
# 10: 1
#
# ቀን: 1
#
# 96: 1
#
# ባለሥልጣናትን: 1
#
# ምሁራንን: 1
#
# ከገደለው: 1
#
# የ: 1
#
# 2010: 1
#
# የፖላንድ: 1
#
# አየር: 1
#
# ኃይል: 1
#
# ቱ: 1
#
# 154: 1
#
# የበረራ: 1
#
# መረጃ: 1
#
# መቅረጫዎችን: 1
#
# ግልባጭ: 1
#
# ለህትመት: 1
#
# አበቃች።: 1
#
# የአሜሪካው: 1
#
# የኦባማ: 1
#
# አስተዳደር: 1
#
# በሜክሲኮ: 1
#
# ባሕረ: 1
#
# ሰላጤ: 1
#
# የቢፒ: 1
#
# የእንግሊዝ: 1
#
# ኩባንያ: 1
#
# የነዳጅ: 1
#
# ዘይት: 1
#
# ፍሰት: 1
#
# እስከ: 1
#
# ነሐሴ: 1
#
# ድረስ: 1
#
# ሊቀጥል: 1
#
# እንደሚችል: 1
#
# አስጠንቅቋል።: 1
#
# ሶስት: 1
#
# የናሚቢያ: 1
#
# ሴቶች: 1
#
# ከፍላጎታችን: 1
#
# ውጪ: 1
#
# ላለመውለድ: 1
#
# የሚያስችለውን: 1
#
# የህክምና: 1
#
# ሂደት: 1
#
# እንድንከታተል: 1
#
# ከተደረገብን: 1
#
# ኤችአይቪ: 1
#
# ተይዘናል: 1
#
# በማለት: 1
#
# መንግስትን: 1
#
# ክስ: 1
#
# አቀረቡ።: 1
#
# በደቡብ: 1
#
# ሰሜን: 1
#
# ኮሪያን: 1
#
# ክዶ: 1
#
# የመጣ: 1
#
# ህዋንግ: 1
#
# ጃንገ: 1
#
# ዮፕ: 1
#
# ከተባለ: 1
#
# ከፍተኛ: 1
#
# ባለስልጣን: 1
#
# ጋር: 1
#
# በተያያዘ: 1
#
# ዜግነት: 1
#
# ያላቸው: 1
#
# ግለሰቦች: 1
#
# ታሰሩ።: 1
#
# በቀድሞው: 1
#
# የብሪታንያ: 1
#
# ቅኝ: 1
#
# በሆንግ: 1
#
# ኮንግ: 1
#
# በተደረገው: 1
#
# ተቃውሞ: 1
#
# 52000: 1
#
# ሃምሳ: 1
#
# ሺህ: 1
#
# የሚገመቱ: 1
#
# ተሳትፈዋል።: 1
#
# የፊንላንድ: 1
#
# ፓርላማ: 1
#
# የኒውክላር: 1
#
# ሃይል: 1
#
# ማመንጫ: 1
#
# ጣቢያዎች: 1
#
# ግንባታ: 1
#
# እንዲጀመር: 1
#
# ወሰነ።: 1
#
#
# የፊደል ድግግሞሽ(Character Frequency):
# ን= 96
#
# የ= 69
#
# ት= 50
#
# አ= 49
#
#
# ቁጥራዊ መርጃ(Statistical Information):
#
# ጠቅላላ መስመር(Total Lines): 20
#
# ጠቅላላ የቃላት ብዛት(Total Words): 359
#
# ጠቅላላ የፊደል ብዛት(Total Characters): 1878
